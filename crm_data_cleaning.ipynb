# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Md Shah Alak\Desktop\accounts.csv")

# %%
df.head()
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
# 3        Bioholding    medical              2012   587.34       1356
# 4           Bioplex    medical              1991   326.82       1016
#
#   office_location subsidiary_of
# 0   United States           NaN
# 1   United States           NaN
# 2           Kenya           NaN
# 3      Philipines           NaN
# 4   United States           NaN

# %%
df4 = pd.read_csv(r"C:\Users\Md Shah Alak\Desktop\sales_pipeline.csv")

# %%
df4
# Out:
#      opportunity_id        sales_agent         product  account   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic  Cancity          Won
# 1          Z063OYW0    Darcel Schlecht          GTXPro    Isdom          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special  Cancity          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic  Codehow          Won
# 4          PE84CX4O          Zane Levy       GTX Basic   Hatfan          Won
# ...             ...                ...             ...      ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced      NaN  Prospecting
#
#      engage_date  close_date  close_value
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8800 entries, 0 to 8799
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   opportunity_id  8800 non-null   object
#  1   sales_agent     8800 non-null   object
#  2   product         8800 non-null   object
#  3   account         7375 non-null   object
#  4   deal_stage      8800 non-null   object
#  5   engage_date     8300 non-null   object
#  6   close_date      6711 non-null   object
#  7   close_value     6711 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 550.1+ KB

# %%
result = df4.drop_duplicates(subset='sales_agent', keep='first')

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 134
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   opportunity_id  30 non-null     object
#  1   sales_agent     30 non-null     object
#  2   product         30 non-null     object
#  3   account         28 non-null     object
#  4   deal_stage      30 non-null     object
#  5   engage_date     30 non-null     object
#  6   close_date      28 non-null     object
#  7   close_value     28 non-null     float64
# dtypes: float64(1), object(7)
# memory usage: 2.1+ KB

# %%
result.shape
# Out:
# (30, 8)

# %%
df4.shape
# Out:
# (8800, 8)

# %%
result2 = df4.drop_duplicates(subset='opportunity_id', keep='first')

# %%
result2
# Out:
#      opportunity_id        sales_agent         product  account   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic  Cancity          Won
# 1          Z063OYW0    Darcel Schlecht          GTXPro    Isdom          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special  Cancity          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic  Codehow          Won
# 4          PE84CX4O          Zane Levy       GTX Basic   Hatfan          Won
# ...             ...                ...             ...      ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced      NaN  Prospecting
#
#      engage_date  close_date  close_value
# ...

# %%
result3 = df4.drop_duplicates(keep='first')

# %%
result3
# Out:
#      opportunity_id        sales_agent         product  account   deal_stage  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic  Cancity          Won
# 1          Z063OYW0    Darcel Schlecht          GTXPro    Isdom          Won
# 2          EC4QE1BX    Darcel Schlecht      MG Special  Cancity          Won
# 3          MV1LWRNH        Moses Frase       GTX Basic  Codehow          Won
# 4          PE84CX4O          Zane Levy       GTX Basic   Hatfan          Won
# ...             ...                ...             ...      ...          ...
# 8795       9MIWFW5J  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand     MG Advanced      NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand     MG Advanced      NaN  Prospecting
#
#      engage_date  close_date  close_value
# ...

# %%
result4 = df4.drop_duplicates(subset=['sales_agent', 'product','account','deal_stage'], keep='first')

# %%
result4
# Out:
#      opportunity_id        sales_agent         product    account  \
# 0          1C1I7A6R        Moses Frase  GTX Plus Basic    Cancity
# 1          Z063OYW0    Darcel Schlecht          GTXPro      Isdom
# 2          EC4QE1BX    Darcel Schlecht      MG Special    Cancity
# 3          MV1LWRNH        Moses Frase       GTX Basic    Codehow
# 4          PE84CX4O          Zane Levy       GTX Basic     Hatfan
# ...             ...                ...             ...        ...
# 8763       ROM4I2T0  Versie Hillebrand      MG Special  Rundofase
# 8764       6QKBZAEQ  Versie Hillebrand      MG Special        NaN
# 8790       FCNN6UY0  Versie Hillebrand     MG Advanced  Ganjaflex
# 8791       8M2O0Q8V  Versie Hillebrand     MG Advanced      Silis
# 8792       WNWI8RJU  Versie Hillebrand     MG Advanced        NaN
#
#        deal_stage engage_date  close_date  close_value
# 0             Won  2016-10-20  2017-03-01       1054.0
# 1             Won  2016-10-25  2017-03-11       4514.0
# ...

# %%
result4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5183 entries, 0 to 8792
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   opportunity_id  5183 non-null   object
#  1   sales_agent     5183 non-null   object
#  2   product         5183 non-null   object
#  3   account         4975 non-null   object
#  4   deal_stage      5183 non-null   object
#  5   engage_date     4970 non-null   object
#  6   close_date      4328 non-null   object
#  7   close_value     4328 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 364.4+ KB

# %%
result4 = result4.dropna(subset=['engage_date'])

# %%
result4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4817 entries, 0 to 8297
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   opportunity_id  4817 non-null   object
#  1   sales_agent     4817 non-null   object
#  2   product         4817 non-null   object
#  3   account         4817 non-null   object
#  4   deal_stage      4817 non-null   object
#  5   engage_date     4817 non-null   object
#  6   close_date      4328 non-null   object
#  7   close_value     4328 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 338.7+ KB

# %%
result4
# Out:
#      opportunity_id       sales_agent         product        account  \
# 0          1C1I7A6R       Moses Frase  GTX Plus Basic        Cancity
# 1          Z063OYW0   Darcel Schlecht          GTXPro          Isdom
# 2          EC4QE1BX   Darcel Schlecht      MG Special        Cancity
# 3          MV1LWRNH       Moses Frase       GTX Basic        Codehow
# 4          PE84CX4O         Zane Levy       GTX Basic         Hatfan
# ...             ...               ...             ...            ...
# 8291       8QJHJXY0   Kary Hendrixson      MG Special     Sunnamplex
# 8292       MSN4ZNU6  Violet Mclelland     MG Advanced     Betasoloin
# 8293       3MXS2HRE      Cassey Cress       GTX Basic      Ganjaflex
# 8296       VDGA4KXA  Violet Mclelland  GTX Plus Basic  Bluth Company
# 8297       6WCNNK5J   Maureen Marcano          GTXPro       Hottechi
#
#      deal_stage engage_date  close_date  close_value
# 0           Won  2016-10-20  2017-03-01       1054.0
# ...

# %%
df
# Out:
#              account         sector  year_established  revenue  employees  \
# 0   Acme Corporation      technolgy              1996  1100.04       2822
# 1         Betasoloin        medical              1999   251.41        495
# 2           Betatech        medical              1986   647.18       1185
# 3         Bioholding        medical              2012   587.34       1356
# 4            Bioplex        medical              1991   326.82       1016
# ..               ...            ...               ...      ...        ...
# 80        Zathunicon         retail              2010    71.12        144
# 81    Zencorporation      technolgy              2011    40.79        142
# 82            Zoomit  entertainment              1992   324.19        978
# 83           Zotware       software              1979  4478.47      13809
# 84          Zumgoity        medical              1984   441.08       1210
#
#    office_location subsidiary_of
# 0    United States           NaN
# ...

# %%
df = df.drop(columns=['subsidiary_of'])

# %%
df
# Out:
#              account         sector  year_established  revenue  employees  \
# 0   Acme Corporation      technolgy              1996  1100.04       2822
# 1         Betasoloin        medical              1999   251.41        495
# 2           Betatech        medical              1986   647.18       1185
# 3         Bioholding        medical              2012   587.34       1356
# 4            Bioplex        medical              1991   326.82       1016
# ..               ...            ...               ...      ...        ...
# 80        Zathunicon         retail              2010    71.12        144
# 81    Zencorporation      technolgy              2011    40.79        142
# 82            Zoomit  entertainment              1992   324.19        978
# 83           Zotware       software              1979  4478.47      13809
# 84          Zumgoity        medical              1984   441.08       1210
#
#    office_location
# 0    United States
# 1    United States
# ...

# %%
df.to_csv('Accounts_Cleaned_Data.csv', index=False)

# %%
result4.to_csv('sales_pipeline_cleaned.csv',index = False)
